# %% [markdown]
# #### Inheritance
# ##### Parent class
# ##### Child class
# ##### Child class will inherit (attributes and functions) from parent class
# ![image.png](attachment:image.png)

# %%
# %pip install pydantic email-validator
# Out:
# Requirement already satisfied: pydantic in c:\users\saura\advance python\repository\venv\lib\site-packages (2.10.2)Note: you may need to restart the kernel to use updated packages.
#
# Collecting email-validator
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\saura\advance python\repository\venv\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\saura\advance python\repository\venv\lib\site-packages (from pydantic) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\saura\advance python\repository\venv\lib\site-packages (from pydantic) (4.12.2)
# Collecting dnspython>=2.0.0 (from email-validator)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: idna>=2.0.0 in c:\users\saura\advance python\repository\venv\lib\site-packages (from email-validator) (3.10)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Installing collected packages: dnspython, email-validator
# Successfully installed dnspython-2.7.0 email-validator-2.2.0

# %%
class Person:
    def __init__(self,name:str,age:int) ->None:
        self.name=name
        self.age= age

    def introduce(self) ->None:
        print(f"My name is {self.name}")
        print(f"I am {self.age} years old")

# %%
class employee(Person):

    def __init__ (self,name:str,age:int,company:str)-> None:
        super().__init__(name,age)
        self.company= company

    def work(self) -> None:
        print(f"I work for {self.company}")

# %%
p1= Person(name="shubham",age=23)
type(p1)
# Out:
# __main__.Person

# %%
p1.name
# Out:
# 'shubham'

# %%
p1.age
# Out:
# 23

# %%
p1.introduce()
# Out:
# My name is shubham
# I am 23 years old

# %%
e1= employee(name="roshan",age=34,company="infosys")
type(e1)
# Out:
# __main__.employee

# %%
e1.name
# Out:
# 'roshan'

# %%
e1.introduce()
# Out:
# My name is roshan
# I am 34 years old

# %%
e1.company
# Out:
# 'infosys'

# %%
e1.work()
# Out:
# I work for infosys

# %%
e1.introduce()
e1.work()
# Out:
# My name is roshan
# I am 34 years old
# I work for infosys

# %%
e1

# %%
p1

# %% [markdown]
# ### Practical application of Inheritance

# %%
# %pip install pydantic email-validator
# Out:
# Requirement already satisfied: pydantic in c:\users\saura\advance python\repository\venv\lib\site-packages (2.10.2)
# Requirement already satisfied: email-validator in c:\users\saura\advance python\repository\venv\lib\site-packages (2.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\saura\advance python\repository\venv\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\saura\advance python\repository\venv\lib\site-packages (from pydantic) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\saura\advance python\repository\venv\lib\site-packages (from pydantic) (4.12.2)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\saura\advance python\repository\venv\lib\site-packages (from email-validator) (2.7.0)
# Requirement already satisfied: idna>=2.0.0 in c:\users\saura\advance python\repository\venv\lib\site-packages (from email-validator) (3.10)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Abrreviations
# 1. gt - greater than
# 2. ge - greater than or equal to
# 3. lt - less than
# 4. le - less than or equal to

# %%
from pydantic import BaseModel, Field, EmailStr
from typing import Literal, List

# %%
class Student(BaseModel):

    roll_no: int = Field(description="Student Roll Number",gt=0)
    name: str = Field(description="Student Name",min_length=3,max_length=50)
    marks: float = Field(description="Student marks",gt=0,lt=100)
    email: EmailStr = Field(description="Student mail",max_length=60)
    gender: Literal["male","female"] = Field(description="Student Gender")
    hobbies: List[str] = Field(description="Student hobbies",default_factory=list)

    def student_info(self):
        print(f"Roll Number :{self.roll_no}")
        print(f"Name :{self.name}")
        print(f"Marks :{self.marks}")
        print(f"Email :{self.email}")
        print(f"Gender :{self.gender}")
        print(f"Hobbies :{self.hobbies}")

# %%
s1 = Student(
    roll_no=101,
    name="aditi",
    marks=87.4,
    email="aditi@test.com",
    gender="female",
    hobbies=["singing","cycling"]
)

# %%
s1
# Out:
# Student(roll_no=101, name='aditi', marks=87.4, email='aditi@test.com', gender='female', hobbies=['singing', 'cycling'])

# %%
type(s1)
# Out:
# __main__.Student

# %%
s1.name
# Out:
# 'aditi'

# %%
s1.email
# Out:
# 'aditi@test.com'

# %%
s1.marks
# Out:
# 87.4

# %%
s1.student_info()
# Out:
# Roll Number :101
# Name :aditi
# Marks :87.4
# Email :aditi@test.com
# Gender :female
# Hobbies :['singing', 'cycling']

# %%
s2 = Student(
    roll_no= "Twenty Two",
    name = 123,
    email = "email",
    gender = "TCS",
    hobbies = (1, 2, 3)
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s2 = Student(
#       2     roll_no= "Twenty Two",
#       3     name = 123,
#       4     email = "email",
#       5     gender = "TCS",
#       6     hobbies = (1, 2, 3)
#       7 )
#
# File c:\Users\saura\Advance Python\repository\venv\Lib\site-packages\pydantic\main.py:214, in BaseModel.__init__(self, **data)
#     212 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213 __tracebackhide__ = True
# --> 214 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     215 if self is not validated_self:
#     216     warnings.warn(
#     217         'A custom validator is returning a value other than `self`.\n'
#     218         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     219         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     220         stacklevel=2,
#     221     )
#
# ValidationError: 8 validation errors for Student
# roll_no
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='Twenty Two', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/int_parsing
# name
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# marks
#   Field required [type=missing, input_value={'roll_no': 'Twenty Two',...', 'hobbies': (1, 2, 3)}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# email
#   value is not a valid email address: An email address must have an @-sign. [type=value_error, input_value='email', input_type=str]
# gender
#   Input should be 'Male' or 'Female' [type=literal_error, input_value='TCS', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/literal_error
# hobbies.0
#   Input should be a valid string [type=string_type, input_value=1, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# hobbies.1
#   Input should be a valid string [type=string_type, input_value=2, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# hobbies.2
#   Input should be a valid string [type=string_type, input_value=3, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type

# %%
s2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 s2
#
# NameError: name 's2' is not defined

# %%
s2 = Student(
    roll_no=101,
    name = "Raman",
    marks = 78.5,
    email = "random",
    gender = "male",
    hobbies= ["Cricket"]
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 s2 = Student(
#       2     roll_no=101,
#       3     name = "Raman",
#       4     marks = 78.5,
#       5     email = "random",
#       6     gender = "male",
#       7     hobbies= ["Cricket"]
#       8 )
#
# File c:\Users\saura\Advance Python\repository\venv\Lib\site-packages\pydantic\main.py:214, in BaseModel.__init__(self, **data)
#     212 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213 __tracebackhide__ = True
# --> 214 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     215 if self is not validated_self:
#     216     warnings.warn(
#     217         'A custom validator is returning a value other than `self`.\n'
#     218         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     219         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     220         stacklevel=2,
#     221     )
#
# ValidationError: 1 validation error for Student
# email
#   value is not a valid email address: An email address must have an @-sign. [type=value_error, input_value='random', input_type=str]

# %%
s2 = Student(
    roll_no=101,
    name = "Raman",
    marks = 78.5,
    email = "raman@gmail.com",
    gender = "male",
    hobbies= ["Cricket"]
)

# %%
s2
# Out:
# Student(roll_no=101, name='Raman', marks=78.5, email='raman@gmail.com', gender='male', hobbies=['Cricket'])

# %%
s2.name
# Out:
# 'Raman'

# %%
s2.student_info()
# Out:
# Roll Number :101
# Name :Raman
# Marks :78.5
# Email :raman@gmail.com
# Gender :male
# Hobbies :['Cricket']

# %% [markdown]
# ### 2. Multilevel inheritance
# 1. 1 parent class
# 2. 1 child class
# 3. many grand child classes

# %%
class Employee2:

    def __init__(self,emp_id:int,name:str) -> None:
        self.emp_id = emp_id
        self.name = name

    def employee_info(self) -> None:
        print(f"Employee Id : {self.emp_id}")
        print(f"Name : {self.name}")

# %%
class Manager(Employee2):
    def __init__(self, emp_id:int, name:str,dept:str) -> None:
        super().__init__(emp_id, name)
        self.dept = dept

    def manager_info(self) -> None:
        print(f"Department : {self.dept}")

# %%
class ProjectManager(Manager):

    def __init__(self, emp_id:int, name:str, dept:str,project:str):
        super().__init__(emp_id, name, dept)
        self.project = project

    def get_project_info(self) -> None:
        print(f"project name : {self.project}")

# %%
e1 = Employee2(emp_id=105,name="suresh")
type(e1)
# Out:
# __main__.Employee2

# %%
e1.emp_id
# Out:
# 105

# %%
e1.employee_info()
# Out:
# Employee Id : 105
# Name : suresh

# %%
m1 = Manager(emp_id=101,name="amit",dept="Engg")

# %%
type(m1)
# Out:
# __main__.Manager

# %%
m1.manager_info()
# Out:
# Department : Engg

# %%
m1.employee_info()
m1.manager_info()
# Out:
# Employee Id : 101
# Name : amit
# Department : Engg

# %%
pm1= ProjectManager(emp_id=102,name="Pradip",dept="data science",project="tesla")
type(pm1)
# Out:
# __main__.ProjectManager

# %%
pm1.dept
# Out:
# 'data science'

# %%
pm1.emp_id
# Out:
# 102

# %%
pm1.get_project_info()
# Out:
# project name : tesla

# %%
pm1.employee_info()
# Out:
# Employee Id : 102
# Name : Pradip

# %%
pm1.employee_info()
pm1.manager_info()
pm1.get_project_info()
# Out:
# Employee Id : 102
# Name : Pradip
# Department : data science
# project name : tesla

# %% [markdown]
# ### Hierarchical inheritance
# 1 parent class and multiple child class
#
# ![image.png](attachment:image.png)

# %%
class User:

    def __init__(self,username:str,email:str)-> None:
        self.username= username
        self.email= email
    
    def user_info(self) -> None:
        print(f"Username :{self.username}")
        print(f"Email :{self.email}")

# %%
class Admin(User):

    def __init__(self, username:str, email:str,access:str)->None:
        super().__init__(username, email)
        self.access = access

    def admin_info(self)->None:
        print(f"Access Level : {self.access}")

# %%
class RegularUser(User):

    def __init__(self, username:str, email:str,subscription:str)->None:
        super().__init__(username, email)
        self.subscription = subscription

    def subscription_info(self):
        print(f"Subscription : {self.subscription}")

# %%
u1 = User(username="Rajesh",email="rajesh@gmail.com")
type(u1)
# Out:
# __main__.User

# %%
u1.email
# Out:
# 'rajesh@gmail.com'

# %%
u1.user_info()
# Out:
# Username :Rajesh
# Email :rajesh@gmail.com

# %%
a1 = Admin(username="admin101", email="admin@etlhive.com", access="partial")
type(a1)
# Out:
# __main__.Admin

# %%
a1.username
# Out:
# 'admin101'

# %%
a1.email
# Out:
# 'admin@etlhive.com'

# %%
a1.admin_info()
# Out:
# Access Level : partial

# %%
a1.user_info()
a1.admin_info()
# Out:
# Username :admin101
# Email :admin@etlhive.com
# Access Level : partial

# %%
r1= RegularUser(username="rahuls4", email="rahuls@gmail.com",subscription="Monthly")
type(r1)
# Out:
# __main__.RegularUser

# %%
r1.username
# Out:
# 'rahuls4'

# %%
r1.email
# Out:
# 'rahuls@gmail.com'

# %%
r1.subscription
# Out:
# 'Monthly'

# %%
r1.user_info()
# Out:
# Username :rahuls4
# Email :rahuls@gmail.com

# %%
r1.user_info()
r1.subscription_info()
# Out:
# Username :rahuls4
# Email :rahuls@gmail.com
# Subscription : Monthly

# %%
r1.admin_info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 r1.admin_info()
#
# AttributeError: 'RegularUser' object has no attribute 'admin_info'
