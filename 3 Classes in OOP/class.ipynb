# %% [markdown]
# # Class in OOP

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a= 34
print(type(a))
# Out:
# <class 'int'>

# %%
b = 23
print(type(b))
# Out:
# <class 'int'>

# %%
c= 25.5
print(type(c))
# Out:
# <class 'float'>

# %%
d= "etlhive"
print(type(d))
# Out:
# <class 'str'>

# %%
e = False
print(type(e))
# Out:
# <class 'bool'>

# %%
d =[1,2,3]
print(type(d))
# Out:
# <class 'list'>

# %%
e = (3,4,5)
print(type(e))
# Out:
# <class 'tuple'>

# %%
import pandas as pd

# %%
emp= {
    "id":[1,2,3],
    "name":["sarthak","Raman","Rahul"],
    "Salary":[35000,25000,15000]
}
type(emp)
# Out:
# dict

# %%
emp_df = pd.DataFrame(emp)
emp_df
# Out:
#    id     name  Salary
# 0   1  sarthak   35000
# 1   2    Raman   25000
# 2   3    Rahul   15000

# %%
print(type(emp_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Attribues
# 1. shape
# 2. columns
# 3. Index
# 4. dtypes
# 5. values

# %%
emp_df.shape
# Out:
# (3, 3)

# %%
emp_df.columns
# Out:
# Index(['id', 'name', 'Salary'], dtype='object')

# %%
emp_df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
emp_df.dtypes
# Out:
# id         int64
# name      object
# Salary     int64
# dtype: object

# %%
emp_df.values
# Out:
# array([[1, 'sarthak', 35000],
#        [2, 'Raman', 25000],
#        [3, 'Rahul', 15000]], dtype=object)

# %% [markdown]
# ### Functions / Methods

# %%
# Incorrect
emp_df.info
# Out:
# <bound method DataFrame.info of    id     name  Salary
# 0   1  sarthak   35000
# 1   2    Raman   25000
# 2   3    Rahul   15000>

# %%
emp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3 non-null      int64
#  1   name    3 non-null      object
#  2   Salary  3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
emp_df.sort_values(by="Salary",ascending=False)
# Out:
#    id     name  Salary
# 0   1  sarthak   35000
# 1   2    Raman   25000
# 2   3    Rahul   15000

# %% [markdown]
# ### Creating a user defined class
# ### self is any object of class person

# %%
class Person:
    # Create a constructor function to define attributes
    def __init__(self,name:str,age:int,gender:str,occupation:str)-> None:
        self.name= name
        self.age= age
        self.gender= gender
        self.occupation= occupation

    # Create a mothod for class
    def introduce(self):
        print(f"Hii my name is {self.name}")
        print(f"my age is {self.age} years")
        print(f"I am {self.gender}")
        print(f"I work as {self.occupation}")

# %%
p1 = Person(name="sarthak",age=25,gender="male",occupation="HR")
print(type(p1))
# Out:
# <class '__main__.Person'>

# %% [markdown]
# ### __main__ means current file which i am working

# %%
p1

# %%
p1.name
# Out:
# 'sarthak'

# %%
p1.age
# Out:
# 25

# %%
p1.gender
# Out:
# 'male'

# %%
p1.occupation
# Out:
# 'HR'

# %%
p1.introduce()
# Out:
# Hii my name is sarthak
# my age is 25 years
# I am male
# I work as HR

# %%
p2= Person(name="pradip",age=22,gender="male",occupation="Engineer")
type(p1)
# Out:
# __main__.Person

# %%
p2.introduce()
# Out:
# Hii my name is pradip
# my age is 22 years
# I am male
# I work as Engineer

# %%
p3 = Person(12, "raman", "HR", "Male")
type(p3)
# Out:
# __main__.Person

# %%
p3.introduce()
# Out:
# Hii my name is 12
# my age is raman years
# I am HR
# I work as Male

# %% [markdown]
# ### Dataclasses

# %%
a=23
assert type(a) == str, "Input should be str"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 a=23
# ----> 2 assert type(a) == str, "Input should be str"
#
# AssertionError: Input should be str

# %%
from dataclasses import dataclass

# %%
from typing import Literal

# %%
a=3
isinstance(a,str)
# Out:
# False

# %%
@dataclass

class Person2:
    name: str
    age: int
    gender: Literal["male","female"]
    occupation: str

    def __post_init__(self):
        errors =[]

        if not isinstance(self.name,str):
            errors.append("Name should be a string")
        
        if not isinstance(self.age, int) or self.age<=0:
            errors.append("Age should be a positive integer")

        if self.gender not in ["male","female"]:
            errors.append("Gender can be either male or female")
        
        if not isinstance(self.occupation,str):
            errors.append("Occupation should be a string")
        
        if errors:
            raise ValueError("\n".join(errors))
        
    def talk(self):
        print(f"My name is {self.name}")
        print(f"My age is {self.age}")
        print(f"I am {self.gender}")
        print(f"I work as a {self.occupation}")

# %%
p5= Person2(name="rahul", age=23, gender="male", occupation="Financial Analyst" )

# %%
p5.name
# Out:
# 'rahul'

# %%
p5.talk()
# Out:
# My name is rahul
# My age is 23
# I am male
# I work as a Financial Analyst

# %%
p6 = Person2(name=23, age=-3, gender="male", occupation="HR")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 p6 = Person2(name=23, age=-3, gender="male", occupation="HR")
#
# File <string>:7, in __init__(self, name, age, gender, occupation)
#
# Cell In[48], line 25, in Person2.__post_init__(self)
#      22     errors.append("Occupation should be a string")
#      24 if errors:
# ---> 25     raise ValueError("\n".join(errors))
#
# ValueError: Name should be a string
# Age should be a positive integer

# %%
p6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 p6
#
# NameError: name 'p6' is not defined

# %%
p6 = Person2(name= "Rahul", age=29, gender="HR", occupation="male")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 p6 = Person2(name= "Rahul", age=29, gender="HR", occupation="male")
#
# File <string>:7, in __init__(self, name, age, gender, occupation)
#
# Cell In[48], line 25, in Person2.__post_init__(self)
#      22     errors.append("Occupation should be a string")
#      24 if errors:
# ---> 25     raise ValueError("\n".join(errors))
#
# ValueError: Gender can be either male or female

# %%
p6 = Person2(name= "Dipak", age=29, gender="male", occupation="HR")

# %%
p6
# Out:
# Person2(name='Dipak', age=29, gender='male', occupation='HR')

# %%
p6.talk()
# Out:
# My name is Dipak
# My age is 29
# I am male
# I work as a HR
